# %%
import numpy as np
import pandas as pd

# %%
ls = pd.Series([1,2,3,4,np.nan,6,8])

# %%
ls
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    6.0
# 6    8.0
# dtype: float64

# %%
datas = pd.date_range("20170101", periods= 100)

# %%
datas
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-14', '2017-01-15', '2017-01-16',
#                '2017-01-17', '2017-01-18', '2017-01-19', '2017-01-20',
#                '2017-01-21', '2017-01-22', '2017-01-23', '2017-01-24',
#                '2017-01-25', '2017-01-26', '2017-01-27', '2017-01-28',
#                '2017-01-29', '2017-01-30', '2017-01-31', '2017-02-01',
#                '2017-02-02', '2017-02-03', '2017-02-04', '2017-02-05',
#                '2017-02-06', '2017-02-07', '2017-02-08', '2017-02-09',
#                '2017-02-10', '2017-02-11', '2017-02-12', '2017-02-13',
#                '2017-02-14', '2017-02-15', '2017-02-16', '2017-02-17',
#                '2017-02-18', '2017-02-19', '2017-02-20', '2017-02-21',
# ...

# %%
df = pd.DataFrame(np.random.randn(100,4),index=datas, columns = list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2017-01-01  0.401015 -0.317791 -1.637546  2.062001
# 2017-01-02  0.606014 -0.156655 -0.649410  0.258308
# 2017-01-03  0.167789  0.343547  0.493826 -1.313448
# 2017-01-04  1.284514  2.767778  1.311354  0.369470
# 2017-01-05 -0.864241 -1.570023  0.559008  0.139228
# ...              ...       ...       ...       ...
# 2017-04-06  0.217928 -0.896386  1.326583 -2.077691
# 2017-04-07  1.453363 -0.106325  0.509812 -0.421858
# 2017-04-08 -0.922346 -0.477090 -0.672134 -0.840427
# 2017-04-09 -0.962623 -0.214485  1.330935 -0.522030
# 2017-04-10  0.409832 -2.137286 -0.113472 -0.276641
#
# [100 rows x 4 columns]

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2017-01-01  0.401015 -0.317791 -1.637546  2.062001
# 2017-01-02  0.606014 -0.156655 -0.649410  0.258308
# 2017-01-03  0.167789  0.343547  0.493826 -1.313448
# 2017-01-04  1.284514  2.767778  1.311354  0.369470
# 2017-01-05 -0.864241 -1.570023  0.559008  0.139228

# %%
df.head(n=10)
# Out:
#                    A         B         C         D
# 2017-01-01  0.401015 -0.317791 -1.637546  2.062001
# 2017-01-02  0.606014 -0.156655 -0.649410  0.258308
# 2017-01-03  0.167789  0.343547  0.493826 -1.313448
# 2017-01-04  1.284514  2.767778  1.311354  0.369470
# 2017-01-05 -0.864241 -1.570023  0.559008  0.139228
# 2017-01-06  0.375208 -1.762507 -1.339868 -1.994172
# 2017-01-07 -0.100508  0.025032  1.160811 -0.843647
# 2017-01-08  0.712112 -0.984780 -0.874571 -0.317793
# 2017-01-09 -2.506412 -0.225643 -0.835878 -0.532473
# 2017-01-10 -2.441216  0.283019  0.476282 -0.735122

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2017-04-06  0.217928 -0.896386  1.326583 -2.077691
# 2017-04-07  1.453363 -0.106325  0.509812 -0.421858
# 2017-04-08 -0.922346 -0.477090 -0.672134 -0.840427
# 2017-04-09 -0.962623 -0.214485  1.330935 -0.522030
# 2017-04-10  0.409832 -2.137286 -0.113472 -0.276641

# %%
df.tail(n=10)
# Out:
#                    A         B         C         D
# 2017-04-01  0.321027 -0.811247 -1.504564  1.417057
# 2017-04-02 -0.982827 -0.536569 -0.556514 -0.371520
# 2017-04-03  1.335856 -1.017111  0.064093 -1.254273
# 2017-04-04 -1.728591 -1.117275 -1.016358 -0.404007
# 2017-04-05 -0.271842  1.429260  1.418512  0.198774
# 2017-04-06  0.217928 -0.896386  1.326583 -2.077691
# 2017-04-07  1.453363 -0.106325  0.509812 -0.421858
# 2017-04-08 -0.922346 -0.477090 -0.672134 -0.840427
# 2017-04-09 -0.962623 -0.214485  1.330935 -0.522030
# 2017-04-10  0.409832 -2.137286 -0.113472 -0.276641

# %%
df.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-14', '2017-01-15', '2017-01-16',
#                '2017-01-17', '2017-01-18', '2017-01-19', '2017-01-20',
#                '2017-01-21', '2017-01-22', '2017-01-23', '2017-01-24',
#                '2017-01-25', '2017-01-26', '2017-01-27', '2017-01-28',
#                '2017-01-29', '2017-01-30', '2017-01-31', '2017-02-01',
#                '2017-02-02', '2017-02-03', '2017-02-04', '2017-02-05',
#                '2017-02-06', '2017-02-07', '2017-02-08', '2017-02-09',
#                '2017-02-10', '2017-02-11', '2017-02-12', '2017-02-13',
#                '2017-02-14', '2017-02-15', '2017-02-16', '2017-02-17',
#                '2017-02-18', '2017-02-19', '2017-02-20', '2017-02-21',
# ...

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.40101525, -0.31779111, -1.63754596,  2.06200109],
#        [ 0.60601418, -0.1566549 , -0.64941049,  0.25830783],
#        [ 0.16778927,  0.34354695,  0.49382559, -1.31344822],
#        [ 1.28451424,  2.7677778 ,  1.31135419,  0.36947027],
#        [-0.86424063, -1.57002331,  0.55900825,  0.13922774],
#        [ 0.37520799, -1.76250748, -1.33986849, -1.99417215],
#        [-0.10050831,  0.0250323 ,  1.16081103, -0.84364713],
#        [ 0.71211227, -0.98478046, -0.87457131, -0.31779276],
#        [-2.50641226, -0.22564255, -0.83587817, -0.53247265],
#        [-2.44121594,  0.28301896,  0.47628247, -0.73512218],
#        [ 0.52411752, -2.1387732 ,  1.19123495,  1.49570434],
#        [ 1.48594575,  0.04161881, -1.03188088,  0.14489257],
#        [-0.44042983,  0.94826001, -0.5817837 ,  0.45337187],
#        [-0.08737974, -0.1087024 ,  1.12298092,  1.1298405 ],
#        [ 0.78362349, -0.29765066,  0.62794155,  0.1511267 ],
# ...

# %%
df.describe()
# Out:
#                 A           B           C           D
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.078736   -0.125953   -0.012713    0.098885
# std      0.960822    1.029296    0.985852    0.981064
# min     -2.506412   -3.019832   -2.490227   -2.469321
# 25%     -0.517786   -0.822462   -0.763076   -0.523904
# 50%      0.161914   -0.114424    0.187289    0.150753
# 75%      0.728924    0.429506    0.672668    0.750236
# max      2.297752    2.767778    1.911494    2.683967

# %%
df.T
# Out:
#    2017-01-01  2017-01-02  2017-01-03  2017-01-04  2017-01-05  2017-01-06  \
# A    0.401015    0.606014    0.167789    1.284514   -0.864241    0.375208
# B   -0.317791   -0.156655    0.343547    2.767778   -1.570023   -1.762507
# C   -1.637546   -0.649410    0.493826    1.311354    0.559008   -1.339868
# D    2.062001    0.258308   -1.313448    0.369470    0.139228   -1.994172
#
#    2017-01-07  2017-01-08  2017-01-09  2017-01-10  ...  2017-04-01  \
# A   -0.100508    0.712112   -2.506412   -2.441216  ...    0.321027
# B    0.025032   -0.984780   -0.225643    0.283019  ...   -0.811247
# C    1.160811   -0.874571   -0.835878    0.476282  ...   -1.504564
# D   -0.843647   -0.317793   -0.532473   -0.735122  ...    1.417057
#
#    2017-04-02  2017-04-03  2017-04-04  2017-04-05  2017-04-06  2017-04-07  \
# A   -0.982827    1.335856   -1.728591   -0.271842    0.217928    1.453363
# B   -0.536569   -1.017111   -1.117275    1.429260   -0.896386   -0.106325
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2017-01-01  2.062001 -1.637546 -0.317791  0.401015
# 2017-01-02  0.258308 -0.649410 -0.156655  0.606014
# 2017-01-03 -1.313448  0.493826  0.343547  0.167789
# 2017-01-04  0.369470  1.311354  2.767778  1.284514
# 2017-01-05  0.139228  0.559008 -1.570023 -0.864241
# ...              ...       ...       ...       ...
# 2017-04-06 -2.077691  1.326583 -0.896386  0.217928
# 2017-04-07 -0.421858  0.509812 -0.106325  1.453363
# 2017-04-08 -0.840427 -0.672134 -0.477090 -0.922346
# 2017-04-09 -0.522030  1.330935 -0.214485 -0.962623
# 2017-04-10 -0.276641 -0.113472 -2.137286  0.409832
#
# [100 rows x 4 columns]

# %%
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2017-01-09 -2.506412 -0.225643 -0.835878 -0.532473
# 2017-01-10 -2.441216  0.283019  0.476282 -0.735122
# 2017-02-11 -1.997127  1.741807  1.799594 -1.214031
# 2017-02-13 -1.896947 -0.377403  0.087060  1.068407
# 2017-04-04 -1.728591 -1.117275 -1.016358 -0.404007
# ...              ...       ...       ...       ...
# 2017-01-12  1.485946  0.041619 -1.031881  0.144893
# 2017-01-17  1.537058  0.374481  0.413688  0.324709
# 2017-03-07  1.558247 -0.176063 -0.122885 -0.127179
# 2017-03-21  1.562100 -0.988526 -2.490227 -1.560926
# 2017-03-18  2.297752  0.758371 -1.821785  0.983013
#
# [100 rows x 4 columns]

# %%
df.["A"]
# Out:
#   File "C:\Users\BAHAAO~1\AppData\Local\Temp/ipykernel_6664/1096379340.py", line 1
#     df.["A"]
#        ^
# SyntaxError: invalid syntax

# %%
df["A"]
# Out:
# 2017-01-01    0.401015
# 2017-01-02    0.606014
# 2017-01-03    0.167789
# 2017-01-04    1.284514
# 2017-01-05   -0.864241
#                 ...
# 2017-04-06    0.217928
# 2017-04-07    1.453363
# 2017-04-08   -0.922346
# 2017-04-09   -0.962623
# 2017-04-10    0.409832
# Freq: D, Name: A, Length: 100, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2017-01-01  0.401015 -0.317791 -1.637546  2.062001
# 2017-01-02  0.606014 -0.156655 -0.649410  0.258308
# 2017-01-03  0.167789  0.343547  0.493826 -1.313448

# %%
df["A"[0:3]]
# Out:
# 2017-01-01    0.401015
# 2017-01-02    0.606014
# 2017-01-03    0.167789
# 2017-01-04    1.284514
# 2017-01-05   -0.864241
#                 ...
# 2017-04-06    0.217928
# 2017-04-07    1.453363
# 2017-04-08   -0.922346
# 2017-04-09   -0.962623
# 2017-04-10    0.409832
# Freq: D, Name: A, Length: 100, dtype: float64

# %%
df["A"][0:3]
# Out:
# 2017-01-01    0.401015
# 2017-01-02    0.606014
# 2017-01-03    0.167789
# Freq: D, Name: A, dtype: float64

# %%
df.loc[datas[0]]
# Out:
# A    0.401015
# B   -0.317791
# C   -1.637546
# D    2.062001
# Name: 2017-01-01 00:00:00, dtype: float64

# %%
df.loc[datas[0],"A"]
# Out:
# 0.40101524943238887

# %%
df.at[datas[0],"A"]
# Out:
# 0.40101524943238887

# %%
df.iloc[3]
# Out:
# A    1.284514
# B    2.767778
# C    1.311354
# D    0.369470
# Name: 2017-01-04 00:00:00, dtype: float64

# %%
df.iloc[0]
# Out:
# A    0.401015
# B   -0.317791
# C   -1.637546
# D    2.062001
# Name: 2017-01-01 00:00:00, dtype: float64

# %%
df.iloc[3:5,2:4]
# Out:
#                    C         D
# 2017-01-04  1.311354  0.369470
# 2017-01-05  0.559008  0.139228

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2017-01-02  0.606014 -0.649410
# 2017-01-03  0.167789  0.493826
# 2017-01-05 -0.864241  0.559008

# %%
df[df["A"] > 0 ]
# Out:
#                    A         B         C         D
# 2017-01-01  0.401015 -0.317791 -1.637546  2.062001
# 2017-01-02  0.606014 -0.156655 -0.649410  0.258308
# 2017-01-03  0.167789  0.343547  0.493826 -1.313448
# 2017-01-04  1.284514  2.767778  1.311354  0.369470
# 2017-01-06  0.375208 -1.762507 -1.339868 -1.994172
# 2017-01-08  0.712112 -0.984780 -0.874571 -0.317793
# 2017-01-11  0.524118 -2.138773  1.191235  1.495704
# 2017-01-12  1.485946  0.041619 -1.031881  0.144893
# 2017-01-15  0.783623 -0.297651  0.627942  0.151127
# 2017-01-17  1.537058  0.374481  0.413688  0.324709
# 2017-01-18  0.170623  0.329297 -0.413317 -0.599099
# 2017-01-19  1.157622 -0.069067 -0.761800  1.495691
# 2017-01-21  1.330747  0.485889  0.545161  0.172213
# 2017-01-23  0.055516  0.363449 -1.457966  1.645601
# 2017-01-28  0.359297 -1.839552 -0.067313  0.411919
# 2017-01-30  0.982501 -1.172390 -1.137932 -0.735899
# 2017-01-31  0.425641 -0.501671  1.055012 -0.448072
# ...

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2017-01-01  0.401015       NaN       NaN  2.062001
# 2017-01-02  0.606014       NaN       NaN  0.258308
# 2017-01-03  0.167789  0.343547  0.493826       NaN
# 2017-01-04  1.284514  2.767778  1.311354  0.369470
# 2017-01-05       NaN       NaN  0.559008  0.139228
# ...              ...       ...       ...       ...
# 2017-04-06  0.217928       NaN  1.326583       NaN
# 2017-04-07  1.453363       NaN  0.509812       NaN
# 2017-04-08       NaN       NaN       NaN       NaN
# 2017-04-09       NaN       NaN  1.330935       NaN
# 2017-04-10  0.409832       NaN       NaN       NaN
#
# [100 rows x 4 columns]

# %%
df2 = df.copy()

# %%
df2.dropna(how="any")
# Out:
#                    A         B         C         D
# 2017-01-01  0.401015 -0.317791 -1.637546  2.062001
# 2017-01-02  0.606014 -0.156655 -0.649410  0.258308
# 2017-01-03  0.167789  0.343547  0.493826 -1.313448
# 2017-01-04  1.284514  2.767778  1.311354  0.369470
# 2017-01-05 -0.864241 -1.570023  0.559008  0.139228
# ...              ...       ...       ...       ...
# 2017-04-06  0.217928 -0.896386  1.326583 -2.077691
# 2017-04-07  1.453363 -0.106325  0.509812 -0.421858
# 2017-04-08 -0.922346 -0.477090 -0.672134 -0.840427
# 2017-04-09 -0.962623 -0.214485  1.330935 -0.522030
# 2017-04-10  0.409832 -2.137286 -0.113472 -0.276641
#
# [100 rows x 4 columns]

# %%
df2.fillna(value=5)
# Out:
#                    A         B         C         D
# 2017-01-01  0.401015 -0.317791 -1.637546  2.062001
# 2017-01-02  0.606014 -0.156655 -0.649410  0.258308
# 2017-01-03  0.167789  0.343547  0.493826 -1.313448
# 2017-01-04  1.284514  2.767778  1.311354  0.369470
# 2017-01-05 -0.864241 -1.570023  0.559008  0.139228
# ...              ...       ...       ...       ...
# 2017-04-06  0.217928 -0.896386  1.326583 -2.077691
# 2017-04-07  1.453363 -0.106325  0.509812 -0.421858
# 2017-04-08 -0.922346 -0.477090 -0.672134 -0.840427
# 2017-04-09 -0.962623 -0.214485  1.330935 -0.522030
# 2017-04-10  0.409832 -2.137286 -0.113472 -0.276641
#
# [100 rows x 4 columns]

# %%
pd.isna(df2)
# Out:
#                 A      B      C      D
# 2017-01-01  False  False  False  False
# 2017-01-02  False  False  False  False
# 2017-01-03  False  False  False  False
# 2017-01-04  False  False  False  False
# 2017-01-05  False  False  False  False
# ...           ...    ...    ...    ...
# 2017-04-06  False  False  False  False
# 2017-04-07  False  False  False  False
# 2017-04-08  False  False  False  False
# 2017-04-09  False  False  False  False
# 2017-04-10  False  False  False  False
#
# [100 rows x 4 columns]

# %%
df.mean()
# Out:
# A    0.078736
# B   -0.125953
# C   -0.012713
# D    0.098885
# dtype: float64

# %%
df.describe()
# Out:
#                 A           B           C           D
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.078736   -0.125953   -0.012713    0.098885
# std      0.960822    1.029296    0.985852    0.981064
# min     -2.506412   -3.019832   -2.490227   -2.469321
# 25%     -0.517786   -0.822462   -0.763076   -0.523904
# 50%      0.161914   -0.114424    0.187289    0.150753
# 75%      0.728924    0.429506    0.672668    0.750236
# max      2.297752    2.767778    1.911494    2.683967

# %%
df.std()
# Out:
# A    0.960822
# B    1.029296
# C    0.985852
# D    0.981064
# dtype: float64

# %%
df.std(1)
# Out:
# 2017-01-01    1.541728
# 2017-01-02    0.541419
# 2017-01-03    0.834951
# 2017-01-04    0.991560
# 2017-01-05    0.964419
#                 ...
# 2017-04-06    1.462499
# 2017-04-07    0.825962
# 2017-04-08    0.197051
# 2017-04-09    0.997105
# 2017-04-10    1.111206
# Freq: D, Length: 100, dtype: float64

# %%
df.mean(1)
# Out:
# 2017-01-01    0.126920
# 2017-01-02    0.014564
# 2017-01-03   -0.077072
# 2017-01-04    1.433279
# 2017-01-05   -0.434007
#                 ...
# 2017-04-06   -0.357392
# 2017-04-07    0.358748
# 2017-04-08   -0.727999
# 2017-04-09   -0.092051
# 2017-04-10   -0.529392
# Freq: D, Length: 100, dtype: float64

# %%
datas2 = pd.date_range("20170101", periods= 6)
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=datas2).shift(2)

# %%
s
# Out:
# 2017-01-01    NaN
# 2017-01-02    NaN
# 2017-01-03    1.0
# 2017-01-04    3.0
# 2017-01-05    5.0
# 2017-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C         D
# 2017-01-01       NaN       NaN       NaN       NaN
# 2017-01-02       NaN       NaN       NaN       NaN
# 2017-01-03 -0.832211 -0.656453 -0.506174 -2.313448
# 2017-01-04 -1.715486 -0.232222 -1.688646 -2.630530
# 2017-01-05 -5.864241 -6.570023 -4.440992 -4.860772
# ...              ...       ...       ...       ...
# 2017-04-06       NaN       NaN       NaN       NaN
# 2017-04-07       NaN       NaN       NaN       NaN
# 2017-04-08       NaN       NaN       NaN       NaN
# 2017-04-09       NaN       NaN       NaN       NaN
# 2017-04-10       NaN       NaN       NaN       NaN
#
# [100 rows x 4 columns]

# %%
df.apply(np.cumsum)
# Out:
#                    A          B         C          D
# 2017-01-01  0.401015  -0.317791 -1.637546   2.062001
# 2017-01-02  1.007029  -0.474446 -2.286956   2.320309
# 2017-01-03  1.174819  -0.130899 -1.793131   1.006861
# 2017-01-04  2.459333   2.636879 -0.481777   1.376331
# 2017-01-05  1.595092   1.066855  0.077232   1.515559
# ...              ...        ...       ...        ...
# 2017-04-06  7.895385  -9.660123 -2.326435  11.949480
# 2017-04-07  9.348748  -9.766448 -1.816622  11.527623
# 2017-04-08  8.426402 -10.243538 -2.488756  10.687196
# 2017-04-09  7.463779 -10.458023 -1.157821  10.165166
# 2017-04-10  7.873611 -12.595309 -1.271293   9.888525
#
# [100 rows x 4 columns]

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    4.804165
# B    5.787610
# C    4.401722
# D    5.153288
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
df = pd.DataFrame(np.random.randn(1000,4), index=ts.index , columns=["A","B","C","D"] )

# %%
df = df.cumsum()

# %%
plt.figure();

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#      Unnamed: 0          A          B         C          D
# 0    2000-01-01   0.784543  -0.112282  0.703689   0.501420
# 1    2000-01-02   3.399637   0.385874  1.960915   0.292768
# 2    2000-01-03   4.719805  -0.894137  2.304738  -0.891464
# 3    2000-01-04   4.616783  -1.191425  2.631453  -0.515619
# 4    2000-01-05   3.980869  -1.741049  1.835279  -1.945083
# ..          ...        ...        ...       ...        ...
# 995  2002-09-22  25.277362  15.257142  0.429893  32.873966
# 996  2002-09-23  25.532295  16.220392  0.784587  33.516866
# 997  2002-09-24  25.894756  15.766477  1.117150  32.974771
# 998  2002-09-25  26.498727  15.548063  0.517336  31.576533
# 999  2002-09-26  27.748582  15.508540 -0.820524  31.107183
#
# [1000 rows x 5 columns]
